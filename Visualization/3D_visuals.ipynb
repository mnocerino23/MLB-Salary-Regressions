# %%
#In this file, I continue to visualize the normalized position player data,
#creating additional 3D representations using Python's matplotlib

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
non_rookies = pd.read_csv('/content/drive/MyDrive/Data_Science_Projects/positionplayers_cleaned.csv')
# Out:
# Mounted at /content/drive

# %%
non_rookies.drop(columns = ['Unnamed: 0'], inplace = True)
non_rookies.head()
# Out:
#    age  stints      G    tap     AB     R      H    db   tr    HR  ...  C  DH  \
# 0   32       1  159.0  693.0  634.0  85.0  180.0  38.0  1.0  33.0  ...  0   0
# 1   23       1  152.0  584.0  531.0  69.0  135.0  25.0  1.0  20.0  ...  0   0
# 2   30       1  111.0  333.0  310.0  42.0   70.0  14.0  0.0  20.0  ...  0   0
# 3   29       1   83.0  234.0  202.0  34.0   55.0   8.0  3.0   5.0  ...  0   0
# 4   29       1  158.0  625.0  556.0  79.0  141.0  33.0  6.0  19.0  ...  0   0
#
#    OF  P  SS  bats_B  bats_L  bats_R  throws_L  throws_R
# 0   0  0   0       0       0       1         0         1
# 1   0  0   1       0       0       1         0         1
# 2   0  0   0       0       1       0         0         1
# 3   0  0   0       1       0       0         0         1
# 4   0  0   1       0       0       1         0         1
#
# [5 rows x 44 columns]

# %%
#Filter out the MLB position players on rookie contracts for visualization purposes
non_rookies = non_rookies.loc[non_rookies['Rookie contract'] == 0]
non_rookies.shape
# Out:
# (257, 44)

# %% [markdown]
# # 3D Scatter Plots

# %%
#In the code below I use various combinations of features to see how both relate to player salary.

# %%
import matplotlib.pyplot as plt
x = non_rookies['ops']
y = non_rookies['WAR']
z = non_rookies['salary']

fig = plt.figure(figsize = (12, 10))
ax = plt.axes(projection ="3d")

ax.scatter3D(x, y, z, color = 'blue', alpha = 0.6)
plt.title('Salary vs. WAR vs. OPS')
ax.set_xlabel('OPS', fontweight ='bold')
ax.set_ylabel('WAR', fontweight ='bold')
ax.set_zlabel('Player Salary', fontweight ='bold')
# Out:
# Text(0.5, 0, 'Player Salary')

# %%
x = non_rookies['ops']
y = non_rookies['age']
z = non_rookies['salary']

fig = plt.figure(figsize = (12, 10))
ax = plt.axes(projection ="3d")

ax.scatter3D(x, y, z, color = 'orange', alpha = 0.6)
plt.title('Salary vs. age vs. OPS')
ax.set_xlabel('OPS', fontweight ='bold')
ax.set_ylabel('age', fontweight ='bold')
ax.set_zlabel('Player Salary', fontweight ='bold')
# Out:
# Text(0.5, 0, 'Player Salary')

# %%
x = non_rookies['ops']
y = non_rookies['SO']
z = non_rookies['salary']

fig = plt.figure(figsize = (12, 10))
ax = plt.axes(projection ="3d")

ax.scatter3D(x, y, z, color = 'magenta', alpha = 0.6)
plt.title('Salary vs. strikeouts vs. OPS')
ax.set_xlabel('OPS', fontweight ='bold')
ax.set_ylabel('Strikeouts', fontweight ='bold')
ax.set_zlabel('Player Salary', fontweight ='bold')
# Out:
# Text(0.5, 0, 'Player Salary')

# %%
x = non_rookies['H']
y = non_rookies['HR']
z = non_rookies['salary']

fig = plt.figure(figsize = (12, 10))
ax = plt.axes(projection ="3d")

ax.scatter3D(x, y, z, color = 'red', alpha = 0.6)
plt.title('Salary vs. homeruns vs. hits')
ax.set_xlabel('H', fontweight ='bold')
ax.set_ylabel('HR', fontweight ='bold')
ax.set_zlabel('Player Salary', fontweight ='bold')
# Out:
# Text(0.5, 0, 'Player Salary')

# %%
x = non_rookies['ops']
y = non_rookies['HR']
z = non_rookies['salary']

fig = plt.figure(figsize = (12, 10))
ax = plt.axes(projection ="3d")

ax.scatter3D(x, y, z, color = 'orange', alpha = 0.6)
plt.title('Salary vs. HR vs. OPS')
ax.set_xlabel('OPS', fontweight ='bold')
ax.set_ylabel('HR', fontweight ='bold')
ax.set_zlabel('Player Salary', fontweight ='bold')
# Out:
# Text(0.5, 0, 'Player Salary')

# %%
x = non_rookies['obp']
y = non_rookies['SB']
z = non_rookies['salary']

fig = plt.figure(figsize = (12, 10))
ax = plt.axes(projection ="3d")

ax.scatter3D(x, y, z, color = 'blue', alpha = 0.4)
plt.title('Salary vs. Stolen Bases vs. OBP')
ax.set_xlabel('OBP', fontweight ='bold')
ax.set_ylabel('Stolen Bases', fontweight ='bold')
ax.set_zlabel('Player Salary', fontweight ='bold')
# Out:
# Text(0.5, 0, 'Player Salary')

# %%
x = non_rookies['G']
y = non_rookies['WAR']
z = non_rookies['salary']

fig = plt.figure(figsize = (12, 10))
ax = plt.axes(projection ="3d")

ax.scatter3D(x, y, z, color = 'orange', alpha = 0.6)
plt.title('Salary vs. WAR vs. Games')
ax.set_xlabel('G', fontweight ='bold')
ax.set_ylabel('WAR', fontweight ='bold')
ax.set_zlabel('Player Salary', fontweight ='bold')
# Out:
# Text(0.5, 0, 'Player Salary')

# %%
x = non_rookies['G']
y = non_rookies['ops']
z = non_rookies['salary']

fig = plt.figure(figsize = (12, 10))
ax = plt.axes(projection ="3d")

ax.scatter3D(x, y, z, color = 'orange', alpha = 0.6)
plt.title('Salary vs. OPS vs. Games')
ax.set_xlabel('Games', fontweight ='bold')
ax.set_ylabel('OPS', fontweight ='bold')
ax.set_zlabel('Player Salary', fontweight ='bold')
# Out:
# Text(0.5, 0, 'Player Salary')

# %% [markdown]
# # 2D scatters with salary as heat pattern:

# %%
import seaborn as sns

# %%
sns.scatterplot(
    data= non_rookies, x="G", y="H", hue = 'salary', size = 'salary',
    sizes=(20, 100)
).set(title = 'Hits vs. Games with Salary')
# Out:
# [Text(0.5, 1.0, 'Hits vs. Games with Salary')]

# %%
sns.scatterplot(
    data= non_rookies, x="G", y="HR", hue = 'salary', size = 'salary',
    sizes=(20, 100)
).set(title = 'Home Runs vs. Games with Salary')
# Out:
# [Text(0.5, 1.0, 'Home Runs vs. Games with Salary')]

# %%
sns.scatterplot(
    data= non_rookies, x="G", y="PRO", hue = 'salary', size = 'salary',
    sizes=(20, 100)
).set(title = 'Pro vs. Games with Salary')
# Out:
# [Text(0.5, 1.0, 'Pro vs. Games with Salary')]

# %%
sns.scatterplot(
    data= non_rookies, x="G", y="GURU", hue = 'salary', size = 'salary',
    sizes=(20, 100)
).set(title = 'GURU vs. Games with Salary')
# Out:
# [Text(0.5, 1.0, 'GURU vs. Games with Salary')]

# %%
sns.scatterplot(
    data= non_rookies, x="avg", y="PRO", hue = 'salary', size = 'salary',
    sizes=(20, 100)
).set(title = 'PRO vs. Batting Average with Salary')
# Out:
# [Text(0.5, 1.0, 'PRO vs. Batting Average with Salary')]

# %%
sns.scatterplot(
    data= non_rookies, x="WAR", y="HR", hue = 'salary', size = 'salary',
    sizes=(20, 100)
).set(title = 'Home Runs vs. Wins Above Replacement with Salary')
# Out:
# [Text(0.5, 1.0, 'Home Runs vs. Wins Above Replacement with Salary')]

# %%
sns.scatterplot(
    data= non_rookies, x="WAR", y="obp", hue = 'salary', size = 'salary',
    sizes=(20, 100)
).set(title = 'OBP vs. WAR with Salary')
# Out:
# [Text(0.5, 1.0, 'OBP vs. WAR with Salary')]

# %%
sns.scatterplot(
    data= non_rookies, x="WAR", y="PRO", hue = 'salary', size = 'salary',
    sizes=(20, 100)
).set(title = 'PRO vs. WAR with Salary')
# Out:
# [Text(0.5, 1.0, 'PRO vs. WAR with Salary')]

# %%
sns.scatterplot(
    data= non_rookies, x="db", y="obp", hue = 'salary', size = 'salary',
    sizes=(20, 100)
).set(title = 'PRO vs. WAR with Salary')
# Out:
# [Text(0.5, 1.0, 'PRO vs. WAR with Salary')]

# %%
sns.scatterplot(
    data= non_rookies, x="db", y="slg", hue = 'salary', size = 'salary',
    sizes=(20, 100)
).set(title = 'Slugging vs. Doubles with Salary')
# Out:
# [Text(0.5, 1.0, 'Slugging vs. Doubles with Salary')]
